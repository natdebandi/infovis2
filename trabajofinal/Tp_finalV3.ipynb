# %%
#pip install fastparquet

# %%
#pip install pyarrow

# %%
#pip install duckdb

# %%
#pip install pandas

# %%
#pip install altair_viewer

# %%
#pip install vega_datasets

# %%
#pip install numpy

# %%
import numpy as np

# %%
import altair as alt
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %% [markdown]
# ### ParticipantStatusLogs

# %%
import duckdb

# %%
con = duckdb.connect(database=':memory:')

# %%
import pandas as pd

# %%
origen = 'G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/VAST-Challenge-2022/Datasets/'
destino= 'G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/'


#for i in range(1,73):
#  print('Procesando el archivo #' + str(i))
#  df = pd.read_csv(origen + 'Activity Logs/ParticipantStatusLogs'+str(i)+'.csv')
#  df.to_parquet(destino + 'ParticipantStatusLogs'+str(i)+'.parquet', compression='gzip')

# %%
source = con.execute("SELECT currentMode, count(*) as count FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/ParticipantStatusLogs*.parquet') group by currentMode;").df()
source.head()
# Out:
#     currentMode     count
# 0        AtHome  69236289
# 1     Transport  10246066
# 2  AtRecreation   5436347
# 3  AtRestaurant   1765430
# 4        AtWork  27239602

# %%
source = con.execute("SELECT * FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/ParticipantStatusLogs*.parquet') limit 3;").df()
source.head()
# Out:
#               timestamp                                 currentLocation  \
# 0  2022-03-01T00:00:00Z  POINT (-2724.6277665310454 6866.2081834436985)
# 1  2022-03-01T00:00:00Z  POINT (-1526.9372331431534 5582.2951345645315)
# 2  2022-03-01T00:00:00Z   POINT (-1360.9905987829304 2108.804385379679)
#
#    participantId currentMode hungerStatus sleepStatus  apartmentId  \
# 0              0      AtHome      JustAte    Sleeping        926.0
# 1              1      AtHome      JustAte    Sleeping        928.0
# 2              2      AtHome      JustAte    Sleeping        291.0
#
#    availableBalance  jobId financialStatus  dailyFoodBudget  weeklyExtraBudget
# 0       1286.519556    254          Stable               12        1104.302570
# 1        860.574204    929          Stable               12         926.714377
# 2       1298.184541    348          Stable               16         848.802876

# %% [markdown]
# ### Attributes

# %%
Apartmentsdf = pd.read_csv(origen + 'Attributes/'+'Apartments' +'.csv')
Apartmentsdf.head()
# Out:
#    apartmentId  rentalCost  maxOccupancy   numberOfRooms  \
# 0            1      768.16              2              4
# 1            2     1014.55              2              1
# 2            3     1057.39              4              3
# 3            4     1259.10              4              3
# 4            5      411.50              1              4
#
#                                         location  buildingId
# 0   POINT (1077.6979444315298 648.4427163702453)         340
# 1  POINT (-185.9292838076562 1520.3270983045118)         752
# 2   POINT (2123.0141855392585 5126.753457243003)         639
# 3   POINT (2103.6301776944765 4266.932930123476)         397
# 4   POINT (7.0589743819342985 79.96163671849988)         628

# %%
Buildingsdf = pd.read_csv(origen + 'Attributes/'+'Buildings' +'.csv')
Buildingsdf.head()
# Out:
#    buildingId                                           location buildingType  \
# 0           1  POLYGON ((350.0638997002585 4595.665606173783,...   Commercial
# 1           2  POLYGON ((-1926.972613718425 2725.610686806701...   Residental
# 2           3  POLYGON ((685.6846002015491 1552.131491805318,...   Commercial
# 3           4  POLYGON ((-976.7845160060303 4542.38209636188,...   Commercial
# 4           5  POLYGON ((1259.3061988755617 3572.726728111263...   Residental
#
#    maxOccupancy                  units
# 0           NaN                    NaN
# 1          12.0  [481,498,534,652,818]
# 2           NaN                  [382]
# 3           NaN                    NaN
# 4           2.0                  [231]

# %%
Employersdf = pd.read_csv(origen + 'Attributes/'+'Employers' +'.csv')
Employersdf.head()
# Out:
#    employerId                                       location  buildingId
# 0         379  POINT (-1849.997168394888 1744.6010147106394)         823
# 1         380    POINT (41.51783767879146 418.7264799744545)         154
# 2         381   POINT (877.2786575380362 1358.5441805909259)         279
# 3         382   POINT (670.3987400004884 1584.4743462106067)           3
# 4         383   POINT (829.9556783260775 2163.4803049897623)         146

# %%
jobsdf = pd.read_csv(origen + 'Attributes/'+'jobs' +'.csv')
jobsdf.head()
# Out:
#    jobId  employerId  hourlyRate   startTime     endTime  \
# 0      0         379   10.000000  7:46:00 AM  3:46:00 PM
# 1      1         379   22.217633  7:31:00 AM  3:31:00 PM
# 2      2         380   10.000000  8:00:00 AM  4:00:00 PM
# 3      3         380   15.312071  7:39:00 AM  3:39:00 PM
# 4      4         381   21.355409  7:53:00 AM  3:53:00 PM
#
#                                    daysToWork educationRequirement
# 0  [Monday,Tuesday,Wednesday,Thursday,Friday]  HighSchoolOrCollege
# 1  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 2  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 3  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 4  [Monday,Tuesday,Wednesday,Thursday,Friday]  HighSchoolOrCollege

# %%
Participantsdf = pd.read_csv(origen + 'Attributes/'+'Participants' +'.csv')
Participantsdf.head()
# Out:
#    participantId  householdSize  haveKids  age       educationLevel  \
# 0              0              3      True   36  HighSchoolOrCollege
# 1              1              3      True   25  HighSchoolOrCollege
# 2              2              3      True   35  HighSchoolOrCollege
# 3              3              3      True   21  HighSchoolOrCollege
# 4              4              3      True   43            Bachelors
#
#   interestGroup  joviality
# 0             H   0.001627
# 1             B   0.328087
# 2             A   0.393470
# 3             I   0.138063
# 4             H   0.857397

# %%
Pubsdf = pd.read_csv(origen + 'Attributes/'+'Pubs' +'.csv')
Pubsdf.head()
# Out:
#    pubId  hourlyCost  maxOccupancy  \
# 0    442    8.281103            64
# 1    443    6.417435            64
# 2    444   12.581806            84
# 3    892   11.642905            96
# 4    893   14.840473            79
#
#                                         location  buildingId
# 0    POINT (964.4380231713202 3991.603473784208)         556
# 1    POINT (1809.880173357865 4339.172426035451)          29
# 2    POINT (770.4279044387976 932.5852003214752)        1012
# 3  POINT (-1524.9573211662105 3815.271490114369)         502
# 4  POINT (-1608.766411449925 3886.4924784954583)         164

# %%
Restaurantsdf = pd.read_csv(origen + 'Attributes/'+'Restaurants' +'.csv')
Restaurantsdf.head()
# Out:
#    restaurantId  foodCost  maxOccupancy   \
# 0           445      5.15             71
# 1           446      4.17             82
# 2           447      5.87            119
# 3           448      4.07             98
# 4           449      5.11             53
#
#                                         location  buildingId
# 0   POINT (631.5130723031391 2001.4772026036535)         304
# 1     POINT (413.840000705876 1194.128694228948)         308
# 2    POINT (497.9967937001494 1624.515148185587)          58
# 3    POINT (698.2411158717262 4392.416668183332)         964
# 4  POINT (1407.7107695149243 4010.4574815269225)         181

# %%
Schoolsdf = pd.read_csv(origen + 'Attributes/'+'Schools' +'.csv')
Schoolsdf.head()
# Out:
#    schoolId  monthlyCost  maxEnrollment  \
# 0         0    12.812445            242
# 1       450    91.143514            418
# 2       900    38.005380            394
# 3      1350    73.197852            384
#
#                                          location  buildingId
# 0   POINT (-376.7505037068263 1607.9843212558562)         662
# 1   POINT (-2597.447677094323 3194.1547530883445)         943
# 2  POINT (-2539.1584040534744 6556.0323181733565)         262
# 3    POINT (-4701.462928834322 5141.762936081409)         123

# %% [markdown]
# ### Journals

# %%
CheckinJournaldf = pd.read_csv(origen + 'Journals/'+'CheckinJournal' +'.csv')
CheckinJournaldf.head()
# Out:
#    participantId             timestamp  venueId   venueType
# 0            619  2022-03-01T05:35:00Z     1798         Pub
# 1             15  2022-03-01T05:50:00Z     1798         Pub
# 2             23  2022-03-01T05:55:00Z      894         Pub
# 3            699  2022-03-01T06:00:00Z     1798         Pub
# 4            876  2022-03-01T06:00:00Z     1804  Restaurant

# %%
FinancialJournaldf = pd.read_csv(origen + 'Journals/'+'FinancialJournal' +'.csv')
FinancialJournaldf.head()
# Out:
#    participantId             timestamp   category       amount
# 0              0  2022-03-01T00:00:00Z       Wage  2472.507559
# 1              0  2022-03-01T00:00:00Z    Shelter  -554.988622
# 2              0  2022-03-01T00:00:00Z  Education   -38.005380
# 3              1  2022-03-01T00:00:00Z       Wage  2046.562206
# 4              1  2022-03-01T00:00:00Z    Shelter  -554.988622

# %%
SocialNetworkdf = pd.read_csv(origen + 'Journals/'+'SocialNetwork' +'.csv')
SocialNetworkdf.head()
# Out:
#               timestamp  participantIdFrom  participantIdTo
# 0  2022-03-01T00:00:00Z                173              180
# 1  2022-03-01T00:00:00Z                178              183
# 2  2022-03-01T00:00:00Z                178              185
# 3  2022-03-01T00:00:00Z                180              173
# 4  2022-03-01T00:00:00Z                183              178

# %%
TravelJournaldf = pd.read_csv(origen + 'Journals/'+'TravelJournal' +'.csv')
TravelJournaldf.head()
# Out:
#    participantId       travelStartTime  travelStartLocationId  \
# 0             23  2022-03-01T05:20:00Z                  532.0
# 1            876  2022-03-01T05:50:00Z                    NaN
# 2            902  2022-03-01T06:05:00Z                    NaN
# 3            919  2022-03-01T06:00:00Z                    NaN
# 4            154  2022-03-01T05:55:00Z                    NaN
#
#           travelEndTime  travelEndLocationId                        purpose  \
# 0  2022-03-01T05:55:00Z                  894  Recreation (Social Gathering)
# 1  2022-03-01T06:00:00Z                 1804                         Eating
# 2  2022-03-01T06:10:00Z                 1801                         Eating
# 3  2022-03-01T06:10:00Z                 1802                         Eating
# 4  2022-03-01T06:10:00Z                  446                         Eating
#
#             checkInTime          checkOutTime  startingBalance  endingBalance
# ...

# %% [markdown]
# # Challange 2 item 3
#
# Participants have given permission to have their daily routines captured. Choose two different participants with different routines and describe their daily patterns, with supporting evidence. Limit your response to 10 images and 500 words.
#
# Tomo los participant ids 0 y 1009

# %%
participant=0 
participant2=1009

# %%
Participantsdf.where(Participantsdf["participantId"]==participant).dropna()
# Out:
#    participantId  householdSize haveKids   age       educationLevel  \
# 0            0.0            3.0     True  36.0  HighSchoolOrCollege
#
#   interestGroup  joviality
# 0             H   0.001627

# %%
Participantsdf.where(Participantsdf["participantId"]==participant2).dropna()
# Out:
#       participantId  householdSize haveKids   age educationLevel  \
# 1009         1009.0            1.0    False  39.0            Low
#
#      interestGroup  joviality
# 1009             B    0.82833

# %%
#Creo un dataframe con la fecha el tiempo en que comienza un estado y la duracion del estado en minutos
Participant0=con.execute("SELECT CAST(timestamp as DATE) as date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance, jobId, financialStatus, dailyFoodBudget, weeklyExtraBudget ,date_diff('minutes',min(CAST(timestamp AS TIMESTAMP)) , max(CAST(timestamp AS TIMESTAMP))) as minutos, min(CAST(timestamp AS TIMESTAMP)) as startStamp FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/ParticipantStatusLogs*.parquet') where participantId=0 group by date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance, jobId, financialStatus, dailyFoodBudget, weeklyExtraBudget Order by date, startStamp;").df()

# %%
Participant2=con.execute("SELECT CAST(timestamp as DATE) as date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance, jobId, financialStatus, dailyFoodBudget, weeklyExtraBudget ,date_diff('minutes',min(CAST(timestamp AS TIMESTAMP)) , max(CAST(timestamp AS TIMESTAMP))) as minutos, min(CAST(timestamp AS TIMESTAMP)) as startStamp FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final//parquet/activity_logs/ParticipantStatusLogs*.parquet') where participantId=1009 group by date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance, jobId, financialStatus, dailyFoodBudget, weeklyExtraBudget Order by date, startStamp;").df()

# %%
#agrego para exportar los datos para Tableu
sql="""SELECT participantId,CAST(timestamp as DATE) as date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance, jobId, financialStatus, dailyFoodBudget, 
weeklyExtraBudget ,date_diff('minutes',min(CAST(timestamp AS TIMESTAMP)) , max(CAST(timestamp AS TIMESTAMP))) as minutos, 
min(CAST(timestamp AS TIMESTAMP)) as startStamp 
FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/ParticipantStatusLogs*.parquet') 
where participantId=0 or participantId=1009 group by participantId,date, currentMode, hungerStatus, sleepStatus, apartmentId, availableBalance,
jobId, financialStatus, dailyFoodBudget, weeklyExtraBudget Order by date, startStamp;"""
#sql
particip=con.execute(sql).df()

# %%
particip.head()
# Out:
#    participantId       date currentMode hungerStatus sleepStatus  apartmentId  \
# 0           1009 2022-03-01      AtHome      JustAte       Awake        663.0
# 1              0 2022-03-01      AtHome      JustAte    Sleeping        926.0
# 2           1009 2022-03-01      AtHome      JustAte    Sleeping        663.0
# 3           1009 2022-03-01      AtHome   BecameFull    Sleeping        663.0
# 4              0 2022-03-01      AtHome   BecameFull    Sleeping        926.0
#
#    availableBalance  jobId financialStatus  dailyFoodBudget  \
# 0       1086.233602    627          Stable               20
# 1       1286.519556    254          Stable               12
# 2       1086.233602    627          Stable               20
# 3       1086.233602    627          Stable               20
# 4       1286.519556    254          Stable               12
#
#    weeklyExtraBudget  minutos          startStamp
# 0         415.682867       15 2022-03-01 00:00:00
# ...

# %%
particip.to_csv('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/dosparticips.csv')

# %%
Participant0.shape
# Out:
# (8212, 12)

# %%
Participant0.isnull().sum()
# Out:
# date                 0
# currentMode          0
# hungerStatus         0
# sleepStatus          0
# apartmentId          0
# availableBalance     0
# jobId                0
# financialStatus      0
# dailyFoodBudget      0
# weeklyExtraBudget    0
# minutos              0
# startStamp           0
# dtype: int64

# %%
Participant0.dtypes
# Out:
# date                 datetime64[ns]
# currentMode                  object
# hungerStatus                 object
# sleepStatus                  object
# apartmentId                 float64
# availableBalance            float64
# jobId                         int64
# financialStatus              object
# dailyFoodBudget               int64
# weeklyExtraBudget           float64
# minutos                       int64
# startStamp           datetime64[ns]
# dtype: object

# %%
Participant0.head()
# Out:
#         date currentMode    hungerStatus sleepStatus  apartmentId  \
# 0 2022-03-01      AtHome         JustAte    Sleeping        926.0
# 1 2022-03-01      AtHome      BecameFull    Sleeping        926.0
# 2 2022-03-01      AtHome  BecomingHungry    Sleeping        926.0
# 3 2022-03-01      AtHome  BecomingHungry       Awake        926.0
# 4 2022-03-01   Transport  BecomingHungry       Awake        926.0
#
#    availableBalance  jobId financialStatus  dailyFoodBudget  \
# 0       1286.519556    254          Stable               12
# 1       1286.519556    254          Stable               12
# 2       1286.519556    254          Stable               12
# 3       1286.519556    254          Stable               12
# 4       1286.519556    254          Stable               12
#
#    weeklyExtraBudget  minutos          startStamp
# 0         1104.30257       45 2022-03-01 00:00:00
# 1         1104.30257      150 2022-03-01 00:50:00
# 2         1104.30257      160 2022-03-01 03:25:00
# ...

# %%
aux=Participant0[['date','currentMode','minutos']].groupby(['date','currentMode']).sum().reset_index()
aux

aux2=Participant2[['date','currentMode','minutos']].groupby(['date','currentMode']).sum().reset_index()
aux2
# Out:
#            date   currentMode  minutos
# 0    2022-03-01        AtHome      455
# 1    2022-03-01  AtRecreation      165
# 2    2022-03-01  AtRestaurant       45
# 3    2022-03-01        AtWork      455
# 4    2022-03-01     Transport      155
# ...         ...           ...      ...
# 1804 2023-05-23        AtHome      840
# 1805 2023-05-23  AtRestaurant       15
# 1806 2023-05-23        AtWork      455
# 1807 2023-05-23     Transport       15
# 1808 2023-05-24        AtHome      250
#
# [1809 rows x 3 columns]

# %%
#Dejo comentado para la presentacion
'''
source = aux

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("minutos:Q", stack=None),
    color="currentMode:N"
).properties(height=400, width=800)
'''
# Out:
# '\nsource = aux\n\nalt.Chart(source).mark_area(opacity=0.3).encode(\n    x="date:T",\n    y=alt.Y("minutos:Q", stack=None),\n    color="currentMode:N"\n).properties(height=400, width=800)\n'

# %%
#Este grafico dibuja agrupando por año y mes

source = aux

selection = alt.selection_multi(fields=['currentMode'], bind='legend')

alt.Chart(source).mark_area().encode(
    alt.X('yearmonth(date):T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(minutos):Q', stack='center', axis=None),
    alt.Color('currentMode:N', scale=alt.Scale(scheme='set1')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
dirdatos='G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/'

source.to_csv('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/part1.csv')

# %%
#Este grafico dibuja agrupando por año y mes

source = aux2

selection = alt.selection_multi(fields=['currentMode'], bind='legend')

alt.Chart(source).mark_area().encode(
    alt.X('yearmonth(date):T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(minutos):Q', stack='center', axis=None),
    alt.Color('currentMode:N', scale=alt.Scale(scheme='set1')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='minutos:Q',
    color='currentMode:N',
    row=alt.Row('currentMode:N')
).properties(height=100, width=700)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='minutos:Q',
    color='currentMode:N',
    row=alt.Row('currentMode:N')
).properties(height=100, width=700)
# Out:
# alt.Chart(...)

# %%
aux=Participant0[['date','sleepStatus','minutos']].groupby(['date','sleepStatus']).sum().reset_index()
aux

aux2=Participant2[['date','sleepStatus','minutos']].groupby(['date','sleepStatus']).sum().reset_index()
aux2
# Out:
#            date     sleepStatus  minutos
# 0    2022-03-01           Awake      840
# 1    2022-03-01        Sleeping      435
# 2    2022-03-02           Awake      870
# 3    2022-03-02  PrepareToSleep        5
# 4    2022-03-02        Sleeping      420
# ...         ...             ...      ...
# 1042 2023-05-22        Sleeping      435
# 1043 2023-05-23           Awake      890
# 1044 2023-05-23        Sleeping      435
# 1045 2023-05-24           Awake       15
# 1046 2023-05-24        Sleeping      235
#
# [1047 rows x 3 columns]

# %%
source = aux

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("minutos:Q", stack=None),
    color="sleepStatus:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("minutos:Q", stack=None),
    color="sleepStatus:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
aux=Participant0[['date','hungerStatus','minutos']].groupby(['date','hungerStatus']).sum().reset_index()
aux

aux2=Participant2[['date','hungerStatus','minutos']].groupby(['date','hungerStatus']).sum().reset_index()
aux2
# Out:
#            date    hungerStatus  minutos
# 0    2022-03-01      BecameFull      510
# 1    2022-03-01  BecomingHungry      425
# 2    2022-03-01          Hungry      135
# 3    2022-03-01         JustAte      115
# 4    2022-03-01        Starving       90
# ...         ...             ...      ...
# 2243 2023-05-23         JustAte      120
# 2244 2023-05-23        Starving       90
# 2245 2023-05-24      BecameFull      130
# 2246 2023-05-24  BecomingHungry       90
# 2247 2023-05-24         JustAte       30
#
# [2248 rows x 3 columns]

# %%
source = aux

selection = alt.selection_multi(fields=['hungerStatus'], bind='legend')

alt.Chart(source).mark_area().encode(
    alt.X('date:T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(minutos):Q', stack='center', axis=None),
    alt.Color('hungerStatus:N', scale=alt.Scale(scheme='category20b')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux2

selection = alt.selection_multi(fields=['hungerStatus'], bind='legend')

alt.Chart(source).mark_area().encode(
    alt.X('date:T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(minutos):Q', stack='center', axis=None),
    alt.Color('hungerStatus:N', scale=alt.Scale(scheme='category20b')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
#Comento para la entrega

'''
source = aux

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='minutos:Q',
    color='hungerStatus:N',
    row=alt.Row('hungerStatus:N')
).properties(height=100, width=700)
'''
# Out:
# "\nsource = aux\n\nalt.Chart(source).transform_filter(\n    alt.datum.symbol != 'GOOG'\n).mark_area().encode(\n    x='date:T',\n    y='minutos:Q',\n    color='hungerStatus:N',\n    row=alt.Row('hungerStatus:N')\n).properties(height=100, width=700)\n"

# %%
aux=Participant0[['date','availableBalance','weeklyExtraBudget']].groupby(['date']).mean().reset_index()
aux
aux2=Participant2[['date','availableBalance','weeklyExtraBudget']].groupby(['date']).mean().reset_index()
aux2
# Out:
#           date  availableBalance  weeklyExtraBudget
# 0   2022-03-01       1119.788185         407.075089
# 1   2022-03-02       1137.643431         417.875281
# 2   2022-03-03       1204.474120         427.930318
# 3   2022-03-04       1220.796040         434.761444
# 4   2022-03-05       1151.687319         400.008621
# ..         ...               ...                ...
# 445 2023-05-20       5690.610655        3274.810163
# 446 2023-05-21       5620.503479        3554.535481
# 447 2023-05-22       5634.674226        3910.186816
# 448 2023-05-23       5699.291232        4348.243023
# 449 2023-05-24       5736.567510        4895.813281
#
# [450 rows x 3 columns]

# %%
source = aux

bar = alt.Chart(source).mark_bar().encode(
    x='date:T',
    y='availableBalance:Q'
)

line = alt.Chart(source).mark_line(color='red').transform_window(
    # The field to average
    rolling_mean='mean(availableBalance)',
    # The number of values before and after the current value to include.
    frame=[-9, 0]
).encode(
    x='date:T',
    y='rolling_mean:Q'
)

(bar + line).properties(width=600)
# Out:
# alt.LayerChart(...)

# %%
source = aux2

bar = alt.Chart(source).mark_bar().encode(
    x='date:T',
    y='availableBalance:Q'
)

line = alt.Chart(source).mark_line(color='red').transform_window(
    # The field to average
    rolling_mean='mean(availableBalance)',
    # The number of values before and after the current value to include.
    frame=[-9, 0]
).encode(
    x='date:T',
    y='rolling_mean:Q'
)

(bar + line).properties(width=600)
# Out:
# alt.LayerChart(...)

# %%
#Comento para la entrega

'''

source = aux

bar = alt.Chart(source).mark_bar().encode(
    x='date:T',
    y='weeklyExtraBudget:Q'
)

line = alt.Chart(source).mark_line(color='red').transform_window(
    # The field to average
    rolling_mean='mean(weeklyExtraBudget)',
    # The number of values before and after the current value to include.
    frame=[-9, 0]
).encode(
    x='date:T',
    y='rolling_mean:Q'
)

(bar + line).properties(width=600)

'''
# Out:
# "\n\nsource = aux\n\nbar = alt.Chart(source).mark_bar().encode(\n    x='date:T',\n    y='weeklyExtraBudget:Q'\n)\n\nline = alt.Chart(source).mark_line(color='red').transform_window(\n    # The field to average\n    rolling_mean='mean(weeklyExtraBudget)',\n    # The number of values before and after the current value to include.\n    frame=[-9, 0]\n).encode(\n    x='date:T',\n    y='rolling_mean:Q'\n)\n\n(bar + line).properties(width=600)\n\n"

# %%
#Comento para la entrega

'''

source = aux2

bar = alt.Chart(source).mark_bar().encode(
    x='date:T',
    y='weeklyExtraBudget:Q'
)

line = alt.Chart(source).mark_line(color='red').transform_window(
    # The field to average
    rolling_mean='mean(weeklyExtraBudget)',
    # The number of values before and after the current value to include.
    frame=[-9, 0]
).encode(
    x='date:T',
    y='rolling_mean:Q'
)

(bar + line).properties(width=600)

'''
# Out:
# "\n\nsource = aux2\n\nbar = alt.Chart(source).mark_bar().encode(\n    x='date:T',\n    y='weeklyExtraBudget:Q'\n)\n\nline = alt.Chart(source).mark_line(color='red').transform_window(\n    # The field to average\n    rolling_mean='mean(weeklyExtraBudget)',\n    # The number of values before and after the current value to include.\n    frame=[-9, 0]\n).encode(\n    x='date:T',\n    y='rolling_mean:Q'\n)\n\n(bar + line).properties(width=600)\n\n"

# %%
ParticipantCheckin=CheckinJournaldf.where(CheckinJournaldf["participantId"]==participant).dropna().reset_index()
del ParticipantCheckin['index']
ParticipantCheckin

ParticipantCheckin2=CheckinJournaldf.where(CheckinJournaldf["participantId"]==participant2).dropna().reset_index()
del ParticipantCheckin2['index']
ParticipantCheckin2
# Out:
#       participantId             timestamp  venueId   venueType
# 0            1009.0  2022-03-01T08:20:00Z    877.0   Workplace
# 1            1009.0  2022-03-01T12:55:00Z    898.0  Restaurant
# 2            1009.0  2022-03-01T13:20:00Z    877.0   Workplace
# 3            1009.0  2022-03-01T17:10:00Z    663.0   Apartment
# 4            1009.0  2022-03-01T17:40:00Z    893.0         Pub
# ...             ...                   ...      ...         ...
# 2974         1009.0  2023-05-24T18:55:00Z   1344.0         Pub
# 2975         1009.0  2023-05-24T19:50:00Z    663.0   Apartment
# 2976         1009.0  2023-05-24T20:35:00Z   1343.0         Pub
# 2977         1009.0  2023-05-24T22:40:00Z    663.0   Apartment
# 2978         1009.0  2023-05-24T23:25:00Z   1343.0         Pub
#
# [2979 rows x 4 columns]

# %%
ParticipantCheckin['timestamp']=ParticipantCheckin['timestamp'].astype('datetime64')
ParticipantCheckin

ParticipantCheckin2['timestamp']=ParticipantCheckin2['timestamp'].astype('datetime64')
ParticipantCheckin2
# Out:
#       participantId           timestamp  venueId   venueType
# 0            1009.0 2022-03-01 08:20:00    877.0   Workplace
# 1            1009.0 2022-03-01 12:55:00    898.0  Restaurant
# 2            1009.0 2022-03-01 13:20:00    877.0   Workplace
# 3            1009.0 2022-03-01 17:10:00    663.0   Apartment
# 4            1009.0 2022-03-01 17:40:00    893.0         Pub
# ...             ...                 ...      ...         ...
# 2974         1009.0 2023-05-24 18:55:00   1344.0         Pub
# 2975         1009.0 2023-05-24 19:50:00    663.0   Apartment
# 2976         1009.0 2023-05-24 20:35:00   1343.0         Pub
# 2977         1009.0 2023-05-24 22:40:00    663.0   Apartment
# 2978         1009.0 2023-05-24 23:25:00   1343.0         Pub
#
# [2979 rows x 4 columns]

# %%
aux=ParticipantCheckin['timestamp'].tolist()
valor=aux.pop(0)
auxdf = pd.DataFrame (aux, columns = ['timestamp'])
auxdf.head()

auxA=ParticipantCheckin2['timestamp'].tolist()
valorA=auxA.pop(0)
auxdfA = pd.DataFrame (auxA, columns = ['timestamp'])
auxdfA.head()
# Out:
#             timestamp
# 0 2022-03-01 12:55:00
# 1 2022-03-01 13:20:00
# 2 2022-03-01 17:10:00
# 3 2022-03-01 17:40:00
# 4 2022-03-01 18:10:00

# %%
aux=ParticipantCheckin['timestamp'].tolist()
valor=aux.pop(-1)
auxdf2 = pd.DataFrame (aux, columns = ['timestamp'])
auxdf2.head()


auxA=ParticipantCheckin2['timestamp'].tolist()
valorA=auxA.pop(-1)
auxdf2A = pd.DataFrame (auxA, columns = ['timestamp'])
auxdf2A.head()
# Out:
#             timestamp
# 0 2022-03-01 08:20:00
# 1 2022-03-01 12:55:00
# 2 2022-03-01 13:20:00
# 3 2022-03-01 17:10:00
# 4 2022-03-01 17:40:00

# %%
ParticipantCheckin=ParticipantCheckin[:-1]
ParticipantCheckin

ParticipantCheckin2=ParticipantCheckin2[:-1]
ParticipantCheckin2
# Out:
#       participantId           timestamp  venueId   venueType
# 0            1009.0 2022-03-01 08:20:00    877.0   Workplace
# 1            1009.0 2022-03-01 12:55:00    898.0  Restaurant
# 2            1009.0 2022-03-01 13:20:00    877.0   Workplace
# 3            1009.0 2022-03-01 17:10:00    663.0   Apartment
# 4            1009.0 2022-03-01 17:40:00    893.0         Pub
# ...             ...                 ...      ...         ...
# 2973         1009.0 2023-05-24 18:20:00    899.0  Restaurant
# 2974         1009.0 2023-05-24 18:55:00   1344.0         Pub
# 2975         1009.0 2023-05-24 19:50:00    663.0   Apartment
# 2976         1009.0 2023-05-24 20:35:00   1343.0         Pub
# 2977         1009.0 2023-05-24 22:40:00    663.0   Apartment
#
# [2978 rows x 4 columns]

# %%
ParticipantCheckin['minutes']=(auxdf['timestamp']-auxdf2['timestamp'])/pd.Timedelta('60s')
ParticipantCheckin.head()


ParticipantCheckin2['minutes']=(auxdfA['timestamp']-auxdf2A['timestamp'])/pd.Timedelta('60s')
ParticipantCheckin2.head()
# Out:
# C:\Users\natal\AppData\Local\Temp\ipykernel_15656\2898586922.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ParticipantCheckin2['minutes']=(auxdfA['timestamp']-auxdf2A['timestamp'])/pd.Timedelta('60s')
#    participantId           timestamp  venueId   venueType  minutes
# 0         1009.0 2022-03-01 08:20:00    877.0   Workplace    275.0
# 1         1009.0 2022-03-01 12:55:00    898.0  Restaurant     25.0
# 2         1009.0 2022-03-01 13:20:00    877.0   Workplace    230.0
# 3         1009.0 2022-03-01 17:10:00    663.0   Apartment     30.0
# 4         1009.0 2022-03-01 17:40:00    893.0         Pub     30.0

# %%
ParticipantCheckin['date']=ParticipantCheckin['timestamp'].dt.date.astype('datetime64')
ParticipantCheckin.head()

ParticipantCheckin2['date']=ParticipantCheckin2['timestamp'].dt.date.astype('datetime64')
ParticipantCheckin2.head()
# Out:
# C:\Users\natal\AppData\Local\Temp\ipykernel_15656\3288611679.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ParticipantCheckin2['date']=ParticipantCheckin2['timestamp'].dt.date.astype('datetime64')
#    participantId           timestamp  venueId   venueType  minutes       date
# 0         1009.0 2022-03-01 08:20:00    877.0   Workplace    275.0 2022-03-01
# 1         1009.0 2022-03-01 12:55:00    898.0  Restaurant     25.0 2022-03-01
# 2         1009.0 2022-03-01 13:20:00    877.0   Workplace    230.0 2022-03-01
# 3         1009.0 2022-03-01 17:10:00    663.0   Apartment     30.0 2022-03-01
# 4         1009.0 2022-03-01 17:40:00    893.0         Pub     30.0 2022-03-01

# %%
aux=ParticipantCheckin[['date','venueType','minutes']].groupby(['date','venueType']).sum().reset_index()
aux

aux2=ParticipantCheckin2[['date','venueType','minutes']].groupby(['date','venueType']).sum().reset_index()
aux2
# Out:
#            date   venueType  minutes
# 0    2022-03-01   Apartment    105.0
# 1    2022-03-01         Pub    290.0
# 2    2022-03-01  Restaurant     75.0
# 3    2022-03-01   Workplace    505.0
# 4    2022-03-02   Apartment   1345.0
# ...         ...         ...      ...
# 1303 2023-05-23   Workplace    505.0
# 1304 2023-05-24   Apartment    135.0
# 1305 2023-05-24         Pub    205.0
# 1306 2023-05-24  Restaurant     60.0
# 1307 2023-05-24   Workplace    505.0
#
# [1308 rows x 3 columns]

# %%
source = aux

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("minutes:Q", stack=None),
    color="venueType:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("minutes:Q", stack=None),
    color="venueType:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
#No entiendo el starting y ending balance

participantTravel=TravelJournaldf.where(TravelJournaldf["participantId"]==participant).dropna().reset_index()
del participantTravel['index']
participantTravel['travelStartTime']=participantTravel['travelStartTime'].astype('datetime64')
participantTravel['travelEndTime']=participantTravel['travelEndTime'].astype('datetime64')
participantTravel['checkInTime']=participantTravel['checkInTime'].astype('datetime64')
participantTravel['checkOutTime']=participantTravel['checkOutTime'].astype('datetime64')
participantTravel['balanceDelta']=participantTravel['endingBalance']-participantTravel['startingBalance']
participantTravel['Travelminutes']=(participantTravel['travelEndTime']-participantTravel['travelStartTime'])/pd.Timedelta('60s')
participantTravel['Checkminutes']=(participantTravel['checkOutTime']-participantTravel['checkInTime'])/pd.Timedelta('60s')
participantTravel['date']=participantTravel['travelStartTime'].dt.date.astype('datetime64')
participantTravel



participantTravel2=TravelJournaldf.where(TravelJournaldf["participantId"]==participant2).dropna().reset_index()
del participantTravel2['index']
participantTravel2['travelStartTime']=participantTravel2['travelStartTime'].astype('datetime64')
participantTravel2['travelEndTime']=participantTravel2['travelEndTime'].astype('datetime64')
participantTravel2['checkInTime']=participantTravel2['checkInTime'].astype('datetime64')
participantTravel2['checkOutTime']=participantTravel2['checkOutTime'].astype('datetime64')
participantTravel2['balanceDelta']=participantTravel2['endingBalance']-participantTravel2['startingBalance']
participantTravel2['Travelminutes']=(participantTravel2['travelEndTime']-participantTravel2['travelStartTime'])/pd.Timedelta('60s')
participantTravel2['Checkminutes']=(participantTravel2['checkOutTime']-participantTravel2['checkInTime'])/pd.Timedelta('60s')
participantTravel2['date']=participantTravel2['travelStartTime'].dt.date.astype('datetime64')
participantTravel2
# Out:
#       participantId     travelStartTime  travelStartLocationId  \
# 0            1009.0 2022-03-01 08:10:00                  663.0
# 1            1009.0 2022-03-01 12:50:00                  877.0
# 2            1009.0 2022-03-01 13:15:00                  898.0
# 3            1009.0 2022-03-01 16:55:00                  877.0
# 4            1009.0 2022-03-01 17:15:00                  663.0
# ...             ...                 ...                    ...
# 2973         1009.0 2023-05-24 18:05:00                 1344.0
# 2974         1009.0 2023-05-24 18:40:00                  899.0
# 2975         1009.0 2023-05-24 19:15:00                 1344.0
# 2976         1009.0 2023-05-24 19:55:00                  663.0
# 2977         1009.0 2023-05-24 22:05:00                 1343.0
#
#            travelEndTime  travelEndLocationId                        purpose  \
# 0    2022-03-01 08:20:00                877.0              Work/Home Commute
# ...

# %%
aux=participantTravel[['date','purpose','Travelminutes']].groupby(['date','purpose']).sum().reset_index()
aux

aux2=participantTravel2[['date','purpose','Travelminutes']].groupby(['date','purpose']).sum().reset_index()
aux2
# Out:
#            date                        purpose  Travelminutes
# 0    2022-03-01    Coming Back From Restaurant           15.0
# 1    2022-03-01                         Eating           15.0
# 2    2022-03-01             Going Back to Home           55.0
# 3    2022-03-01  Recreation (Social Gathering)           90.0
# 4    2022-03-01              Work/Home Commute           25.0
# ...         ...                            ...            ...
# 1467 2023-05-24    Coming Back From Restaurant           20.0
# 1468 2023-05-24                         Eating           20.0
# 1469 2023-05-24             Going Back to Home           70.0
# 1470 2023-05-24  Recreation (Social Gathering)           80.0
# 1471 2023-05-24              Work/Home Commute           25.0
#
# [1472 rows x 3 columns]

# %%
#Comento para la presentacion

'''
source = aux

alt.Chart(source).mark_area(opacity=0.3).encode(
    x="date:T",
    y=alt.Y("Travelminutes:Q", stack=None),
    color="purpose:N"
).properties(height=400, width=800)
'''
# Out:
# '\nsource = aux\n\nalt.Chart(source).mark_area(opacity=0.3).encode(\n    x="date:T",\n    y=alt.Y("Travelminutes:Q", stack=None),\n    color="purpose:N"\n).properties(height=400, width=800)\n'

# %%
#Comento para la presentacion
'''
source = aux

alt.Chart(source).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    x='date:T',
    y='count():Q',
    color='purpose:N'
).properties(height=200, width=800)
'''
# Out:
# "\nsource = aux\n\nalt.Chart(source).mark_bar(\n    cornerRadiusTopLeft=3,\n    cornerRadiusTopRight=3\n).encode(\n    x='date:T',\n    y='count():Q',\n    color='purpose:N'\n).properties(height=200, width=800)\n"

# %%
source = aux

alt.Chart(source).mark_area().encode(
    x="date:T",
    y=alt.Y("Travelminutes:Q", stack="normalize"),
    color="purpose:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).mark_area().encode(
    x="date:T",
    y=alt.Y("Travelminutes:Q", stack="normalize"),
    color="purpose:N"
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
source = aux

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='Travelminutes:Q',
    color='purpose:N',
    row=alt.Row('purpose:N')
).properties(height=100, width=700)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='Travelminutes:Q',
    color='purpose:N',
    row=alt.Row('purpose:N')
).properties(height=100, width=700)
# Out:
# alt.Chart(...)

# %%
source = aux

alt.Chart(source).mark_circle().encode(
    x='date:T',
    y='day(date):O',
    color='purpose:N',
    size='sum(Travelminutes):Q',
    row=alt.Row('purpose:N')
).properties(height=400, width=600)
# Out:
# alt.Chart(...)

# %%
source = aux2

alt.Chart(source).mark_circle().encode(
    x='date:T',
    y='day(date):O',
    color='purpose:N',
    size='sum(Travelminutes):Q',
    row=alt.Row('purpose:N')
).properties(height=400, width=600)
# Out:
# alt.Chart(...)

# %%
#comento para la presentacion

'''
source = aux

alt.Chart(source).mark_circle().encode(
    x='date:T',
    y='day(date):O',
    color='purpose:N',
    size='sum(Travelminutes):Q',
).properties(height=400, width=600)

'''
# Out:
# "\nsource = aux\n\nalt.Chart(source).mark_circle().encode(\n    x='date:T',\n    y='day(date):O',\n    color='purpose:N',\n    size='sum(Travelminutes):Q',\n).properties(height=400, width=600)\n\n"

# %%
#comento para la presentacion

'''

source = aux

alt.Chart(source).mark_circle(
    opacity=0.8,
    stroke='black',
    strokeWidth=1
).encode(
    alt.X('date:T', axis=alt.Axis(labelAngle=0)),
    alt.Y('purpose:N'),
    alt.Size('Travelminutes:Q',
        scale=alt.Scale(range=[0, 4000]),
        legend=alt.Legend(title='Annual Global Deaths')
    ),
    alt.Color('purpose:N', legend=None)
).properties(
    width=450,
    height=320
).transform_filter(
    alt.datum.Entity != 'All natural disasters'
)
'''
# Out:
# "\n\nsource = aux\n\nalt.Chart(source).mark_circle(\n    opacity=0.8,\n    stroke='black',\n    strokeWidth=1\n).encode(\n    alt.X('date:T', axis=alt.Axis(labelAngle=0)),\n    alt.Y('purpose:N'),\n    alt.Size('Travelminutes:Q',\n        scale=alt.Scale(range=[0, 4000]),\n        legend=alt.Legend(title='Annual Global Deaths')\n    ),\n    alt.Color('purpose:N', legend=None)\n).properties(\n    width=450,\n    height=320\n).transform_filter(\n    alt.datum.Entity != 'All natural disasters'\n)\n"

# %% [markdown]
# # Challange 3 item 2
#
# How does the financial health of the residents change over the period covered by the dataset? How do wages compare to the overall cost of living in Engagement? Are there groups that appear to exhibit similar patterns? Describe your rationale for your answers. Limit your response to 10 images and 500 words.

# %%
business= FinancialJournaldf 
business['timestamp']=business['timestamp'].astype('datetime64')
business['amount']=business['amount']
business['date']=business['timestamp'].dt.date.astype('datetime64')
business.head()
# Out:
#    participantId  timestamp   category       amount       date
# 0              0 2022-03-01       Wage  2472.507559 2022-03-01
# 1              0 2022-03-01    Shelter  -554.988622 2022-03-01
# 2              0 2022-03-01  Education   -38.005380 2022-03-01
# 3              1 2022-03-01       Wage  2046.562206 2022-03-01
# 4              1 2022-03-01    Shelter  -554.988622 2022-03-01

# %%
aux=business[['date','category','amount']].groupby(['date','category']).sum().reset_index()
aux.head()
# Out:
#         date        category        amount
# 0 2022-03-01       Education -2.870768e+04
# 1 2022-03-01            Food -1.215839e+04
# 2 2022-03-01      Recreation -2.792102e+04
# 3 2022-03-01  RentAdjustment  2.910119e+04
# 4 2022-03-01         Shelter -1.130395e+06

# %%
#Este grafico dibuja agrupando por año y mes

source = aux

selection = alt.selection_multi(fields=['category'], bind='legend')

alt.Chart(source).mark_area().encode(
    alt.X('yearmonth(date):T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('sum(amount):Q', stack='center', axis=None),
    alt.Color('category:N', scale=alt.Scale(scheme='category20b')),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(height=400, width=800)
# Out:
# alt.Chart(...)

# %%
participantTravel=TravelJournaldf
participantTravel['travelStartTime']=participantTravel['travelStartTime'].astype('datetime64')
participantTravel['travelEndTime']=participantTravel['travelEndTime'].astype('datetime64')
participantTravel['checkInTime']=participantTravel['checkInTime'].astype('datetime64')
participantTravel['checkOutTime']=participantTravel['checkOutTime'].astype('datetime64')
participantTravel['balanceDelta']=participantTravel['endingBalance']-participantTravel['startingBalance']
participantTravel['Travelminutes']=(participantTravel['travelEndTime']-participantTravel['travelStartTime'])/pd.Timedelta('60s')
participantTravel['Checkminutes']=(participantTravel['checkOutTime']-participantTravel['checkInTime'])/pd.Timedelta('60s')
participantTravel['date']=participantTravel['travelStartTime'].dt.date.astype('datetime64')
participantTravel['year'] = pd.DatetimeIndex(participantTravel['date']).year
participantTravel['month'] = pd.DatetimeIndex(participantTravel['date']).month
participantTravel['yearMonth']=participantTravel['month'].astype(str)  + '-' + participantTravel['year'].astype(str) 
participantTravel['Quarter']=participantTravel['month']//4 + 1
participantTravel['QuarterYear']=participantTravel['Quarter'].astype(str)  + '-' + participantTravel['year'].astype(str) 
participantTravel.head()
# Out:
#    participantId     travelStartTime  travelStartLocationId  \
# 0             23 2022-03-01 05:20:00                  532.0
# 1            876 2022-03-01 05:50:00                    NaN
# 2            902 2022-03-01 06:05:00                    NaN
# 3            919 2022-03-01 06:00:00                    NaN
# 4            154 2022-03-01 05:55:00                    NaN
#
#         travelEndTime  travelEndLocationId                        purpose  \
# 0 2022-03-01 05:55:00                  894  Recreation (Social Gathering)
# 1 2022-03-01 06:00:00                 1804                         Eating
# 2 2022-03-01 06:10:00                 1801                         Eating
# 3 2022-03-01 06:10:00                 1802                         Eating
# 4 2022-03-01 06:10:00                  446                         Eating
#
#           checkInTime        checkOutTime  startingBalance  endingBalance  \
# 0 2022-03-01 05:55:00 2022-03-01 06:00:00       851.223425     850.197491
# ...

# %%
aux=participantTravel[['QuarterYear','participantId','endingBalance']].groupby(['participantId','QuarterYear']).mean().reset_index()
aux=aux.head(5000)
aux
# Out:
#       participantId QuarterYear  endingBalance
# 0                 0      1-2022    5543.841404
# 1                 0      1-2023   90617.250735
# 2                 0      2-2022   27148.282687
# 3                 0      2-2023  109441.511347
# 4                 0      3-2022   55940.935633
# ...             ...         ...            ...
# 4995            941      3-2022   13225.922952
# 4996            941      4-2022   17620.788687
# 4997            942      1-2022    1866.975739
# 4998            942      1-2023    7176.846802
# 4999            942      2-2022    2795.023753
#
# [5000 rows x 3 columns]

# %%
source = aux

alt.Chart(source).mark_rect().encode(
    alt.X('QuarterYear:O'),
    alt.Y('participantId:Q'),
    alt.Color('endingBalance:Q', scale=alt.Scale(scheme='greenblue'))
).properties(height=500, width=800)
# Out:
# alt.Chart(...)

# %%
#comento para la presentacion
'''

source = aux

alt.Chart(
    source,
    title="heatMap"
).mark_rect().encode(
    x='QuarterYear:O',
    y='participantId:Q',
    color=alt.Color('max(endingBalance):Q', scale=alt.Scale(scheme="inferno")),
    tooltip=[
        alt.Tooltip('QuarterYear:O', title='Date'),
        alt.Tooltip('max(endingBalance):Q', title='$$$')
    ]
).properties(width=550)

'''
# Out:
# '\n\nsource = aux\n\nalt.Chart(\n    source,\n    title="heatMap"\n).mark_rect().encode(\n    x=\'QuarterYear:O\',\n    y=\'participantId:Q\',\n    color=alt.Color(\'max(endingBalance):Q\', scale=alt.Scale(scheme="inferno")),\n    tooltip=[\n        alt.Tooltip(\'QuarterYear:O\', title=\'Date\'),\n        alt.Tooltip(\'max(endingBalance):Q\', title=\'$$$\')\n    ]\n).properties(width=550)\n\n'

# %%
aux=participantTravel[['QuarterYear','participantId','endingBalance']].groupby(['participantId','QuarterYear']).mean().reset_index()

# %%
aux2=aux.where(aux["QuarterYear"]=='1-2022').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 10000], step=1000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
aux2=aux.where(aux["QuarterYear"]=='2-2022').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 60000], step=5000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
aux2=aux.where(aux["QuarterYear"]=='3-2022').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 120000], step=10000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
aux2=aux.where(aux["QuarterYear"]=='4-2022').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 120000], step=10000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
aux2=aux.where(aux["QuarterYear"]=='1-2023').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 120000], step=10000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
aux2=aux.where(aux["QuarterYear"]=='2-2023').dropna().reset_index()
del aux2['index']

source=aux2

base = alt.Chart(source)

bar = base.mark_bar().encode(
    x=alt.X("endingBalance:Q", bin=alt.Bin(extent=[0, 120000], step=10000),axis=alt.Axis(title="Ending balance", labelAngle=0)),
    y=alt.Y('count()',axis=alt.Axis(title="Number of participants", labelAngle=0))
)

rule = base.mark_rule(color='red').encode(
    x='mean(endingBalance):Q',
    size=alt.value(5)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
dirdatos='G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/'

# %%
Participantsdf = pd.read_csv(origen + 'Attributes/'+'Participants' +'.csv')
Participantsdf.head()
# Out:
#    participantId  householdSize  haveKids  age       educationLevel  \
# 0              0              3      True   36  HighSchoolOrCollege
# 1              1              3      True   25  HighSchoolOrCollege
# 2              2              3      True   35  HighSchoolOrCollege
# 3              3              3      True   21  HighSchoolOrCollege
# 4              4              3      True   43            Bachelors
#
#   interestGroup  joviality
# 0             H   0.001627
# 1             B   0.328087
# 2             A   0.393470
# 3             I   0.138063
# 4             H   0.857397

# %%
source = con.execute("SELECT * FROM read_parquet('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/parquet/activity_logs/ParticipantStatusLogs*.parquet') where participantId IN (1,7,14,23,31);").df()
source
# Out:
#                    timestamp                                 currentLocation  \
# 0       2022-03-01T00:00:00Z  POINT (-1526.9372331431534 5582.2951345645315)
# 1       2022-03-01T00:00:00Z  POINT (-1023.8165705255449 1578.3713681439597)
# 2       2022-03-01T00:00:00Z   POINT (1591.8298888318336 4013.7639158217444)
# 3       2022-03-01T00:00:00Z   POINT (-1107.227708359132 3065.5453427229895)
# 4       2022-03-01T00:00:00Z  POINT (-1189.5514924340619 2890.7553818484876)
# ...                      ...                                             ...
# 646385  2023-05-24T04:30:00Z  POINT (-1526.9372331431534 5582.2951345645315)
# 646386  2023-05-24T04:30:00Z  POINT (-1023.8165705255449 1578.3713681439597)
# 646387  2023-05-24T04:30:00Z   POINT (1591.8298888318336 4013.7639158217444)
# 646388  2023-05-24T04:30:00Z   POINT (-1107.227708359132 3065.5453427229895)
# 646389  2023-05-24T04:30:00Z  POINT (-1189.5514924340619 2890.7553818484876)
#
# ...

# %%
source.to_csv('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/logparticipantes.csv')

# %%
CheckinJournaldf = pd.read_csv(origen + 'Journals/'+'CheckinJournal' +'.csv')
CheckinJournaldf.head()
CheckinJournaldf.to_csv('G:/My Drive/_NAT2022/ITBA/Visualizacion datos/Trabajo final/datos_proc/checkingjournal.csv')
