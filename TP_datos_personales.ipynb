# %% [markdown]
# <a href="https://colab.research.google.com/github/natdebandi/infovis2/blob/main/TP_datos_personales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Analisis de datos personales**

# %% [markdown]
# El objetivo es analizar el uso personal de las redes sociales y otras herramientas virtuales durante un mes (o el período posible)

# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install duckdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import duckdb

# %%
#esto es para poder leer los datos desde el drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # REACCIONES EN DISTINTAS PLATAFORMAS

# %%
#conecto con duckdb y creo una tabla
con = duckdb.connect(database=':memory:')
sql="""Create table reactions (date_event DATE, name VARCHAR, reaction VARCHAR);"""
source = con.execute(sql).df()
source.head()
# Out:
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
#sql="""insert into reactions (date_event, name, reaction) values ('2008-01-01', 'facebook', 'test');"""
#source = con.execute(sql).df()
#source.head()

# %% [markdown]
# ##1. Reacciones y post de FACEBOOK

# %%
## 1. leo las reacciones 
dffb = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/FB_reactions.csv')
dffb.head()
# Out:
#    Unnamed: 0                 date reaction  \
# 0           0  2021-11-05 13:56:41     LOVE
# 1           1  2021-11-05 16:40:09     LOVE
# 2           2  2021-11-06 16:45:08     LOVE
# 3           3  2021-11-06 16:45:29     LOVE
# 4           4  2021-11-07 00:35:38     LOVE
#
#   reactions_v2/data/0/reaction/actor  \
# 0                        Nat Debandi
# 1                        Nat Debandi
# 2                        Nat Debandi
# 3                        Nat Debandi
# 4                        Nat Debandi
#
#                            reactions_v2/title
# 0  Nat Debandi reaccionÃ³ a una publicaciÃ³n.
# 1  Nat Debandi reaccionÃ³ a una publicaciÃ³n.
# 2  Nat Debandi reaccionÃ³ a una publicaciÃ³n.
# 3  Nat Debandi reaccionÃ³ a una publicaciÃ³n.
# 4  Nat Debandi reaccionÃ³ a una publicaciÃ³n.

# %%
"inserto las reacciones"
sql="""insert into reactions (date_event, name, reaction) (SELECT date, 'Facebook',reaction FROM dffb)"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0   1296

# %%
## 2. leo los post
dffb = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/FBpost_completo.csv')
dffb
# Out:
#       Unnamed: 0                 date  \
# 0              0  2008-09-22 20:59:21
# 1              1  2008-09-27 11:54:32
# 2              2  2008-09-28 10:05:30
# 3              3  2008-09-30 21:47:36
# 4              4  2008-10-01 21:23:22
# ...          ...                  ...
# 2164        2164  2022-10-20 19:08:34
# 2165        2165  2022-11-04 14:06:41
# 2166        2166  2022-11-08 13:22:26
# 2167        2167  2022-11-08 21:35:15
# 2168        2168  2022-11-13 12:55:50
#
#                                                    data
# 0       [{'post': 'is comiendo buÃ±uelos de espinaca'}]
# 1                [{'post': 'va a hacer alfaljorcitos'}]
# 2                            [{'post': 'domingueando'}]
# 3       [{'post': 'is diciendole feliz cumple a daro'}]
# 4                                  [{'post': 'duerme'}]
# ...                                                 ...
# 2164                  [{'post': 'FELIZ CUMPLE IUDIII'}]
# ...

# %%
sql="""insert into reactions (date_event, name, reaction) (SELECT date, 'Facebook','post' FROM dffb)"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0   2169

# %%
sql="""select name, reaction, count(*) from reactions group by name, reaction;"""
source = con.execute(sql).df()
source
# Out:
#        name reaction  count_star()
# 0  Facebook     LOVE          1039
# 1  Facebook     LIKE           172
# 2  Facebook  SUPPORT            48
# 3  Facebook     HAHA            27
# 4  Facebook    ANGER             2
# 5  Facebook      WOW             3
# 6  Facebook    SORRY             5
# 7  Facebook     post          2169

# %% [markdown]
# ##2. Linkedin
# ### Incorporo las reaciones de linkedin y los post

# %%
## 2. levanto el archivo de linkedn de reacciones
dflnk = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/linkedin_reactions.csv')
dflnk.head()
# Out:
#                   Date  Type  \
# 0  2022-11-19 10:27:48  LIKE
# 1  2022-11-18 23:03:59  LIKE
# 2  2022-11-17 15:35:20  LIKE
# 3  2022-11-17 15:32:08  LIKE
# 4  2022-11-13 19:58:57  LIKE
#
#                                                 Link
# 0  https://www.linkedin.com/feed/update/urn%3Ali%...
# 1  https://www.linkedin.com/feed/update/urn%3Ali%...
# 2  https://www.linkedin.com/feed/update/urn%3Ali%...
# 3  https://www.linkedin.com/feed/update/urn%3Ali%...
# 4  https://www.linkedin.com/feed/update/urn%3Ali%...

# %%
##inserto las reacciones de linkedin
sql="""insert into reactions (date_event, name, reaction) (SELECT date, 'Linkedin',type FROM dflnk)"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0    413

# %%
sql="""select name,count(*) from reactions group by name;"""
source = con.execute(sql).df()
source.head()
# Out:
#        name  count_star()
# 0  Facebook          3465
# 1  Linkedin           413

# %%
## 2. levanto el archivo de linkedn de conexiones, las incluyo como parte de las reacciones

dflnk2 = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/linkedin_connections2.csv')
dflnk2.head()
# Out:
#            FirstName            Last Name Email Address  \
# 0             German               Santos           NaN
# 1  Alejandro Nicolás            Fernández           NaN
# 2             Ariana                Gómez           NaN
# 3            Facundo  Malaureille Peltzer           NaN
# 4             Martín             Ferreyra           NaN
#
#                                              Company  \
# 0  Estudio Contable- Asesoramiento empresarial, c...
# 1         Asociación Argentina de Ética y Compliance
# 2                               Gobierno de La Pampa
# 3                              Data Governance Latam
# 4                                 Grupo Convergencia
#
#                                             Position ConnectedOn
# 0                       Contador auxiliar de gestión  11-18-2022
# 1                                 Compliance Officer  11-11-2022
# 2  Directora de Seguimiento y Evaluación de Polít...  11-10-2022
# ...

# %%
dflnk2['ConnectedOn']=pd.to_datetime(dflnk2['ConnectedOn'],format='%m-%d-%Y')

# %%
##inserto las conexiones como reacciones e linkedin
sql="""insert into reactions (date_event, name, reaction) (SELECT ConnectedOn, 'Linkedin','Connection' FROM dflnk2)"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0    635

# %%
##incorporo los post de linkedin
dflnk2 = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/linkedin_messages.csv')
dflnk2.head()
# Out:
#                                      CONVERSATION ID      CONVERSATION TITLE  \
# 0  2-YTM5Yzk3MDctNTAzYS00YjZjLWFmOTEtYTUwYTc0NTM1...  Sponsored Conversation
# 1  2-MzM5YTVlZmEtMWUwYi00NWUwLTlmNTUtNzhmZDE2ODI2...                     NaN
# 2  2-MzM5YTVlZmEtMWUwYi00NWUwLTlmNTUtNzhmZDE2ODI2...                     NaN
# 3  2-MzM5YTVlZmEtMWUwYi00NWUwLTlmNTUtNzhmZDE2ODI2...                     NaN
# 4  2-MzM5YTVlZmEtMWUwYi00NWUwLTlmNTUtNzhmZDE2ODI2...                     NaN
#
#                           FROM                             SENDER PROFILE URL  \
# 0              LinkedIn Member                                            NaN
# 1              Natalia Debandi  https://www.linkedin.com/in/natalia-debandiar
# 2  Facundo Malaureille Peltzer         https://www.linkedin.com/in/facundomp1
# 3  Facundo Malaureille Peltzer         https://www.linkedin.com/in/facundomp1
# 4  Facundo Malaureille Peltzer         https://www.linkedin.com/in/facundomp1
#
# ...

# %%
#dflnk2['date']=pd.to_datetime(dflnk2['date'],format='%Y-%m-%d')
##inserto los mensajes de linkedin
sql="""insert into reactions (date_event, name, reaction) (SELECT date, 'Linkedin','Message' FROM dflnk2)"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0    122

# %%
sql="""select name,reaction,count(*) from reactions group by name,reaction;"""
source = con.execute(sql).df()
source
# Out:
#         name    reaction  count_star()
# 0   Facebook        LOVE          1039
# 1   Facebook        LIKE           172
# 2   Facebook     SUPPORT            48
# 3   Facebook        HAHA            27
# 4   Facebook       ANGER             2
# 5   Facebook         WOW             3
# 6   Facebook       SORRY             5
# 7   Facebook        post          2169
# 8   Linkedin        LIKE           407
# 9   Linkedin     EMPATHY             6
# 10  Linkedin  Connection           635
# 11  Linkedin     Message           122

# %% [markdown]
# 3. Incorpóro algunas de las apps de Google: youtube, photos y Play

# %%
dfgoogle = pd.read_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/google_log.csv')
dfgoogle.head()
# Out:
#         Gaia ID       Activity Timestamp  \
# 0  533239498623  2022-10-28 06:57:28 UTC
# 1  533239498623  2022-10-28 06:05:33 UTC
# 2  533239498623  2022-10-28 05:59:36 UTC
# 3  533239498623  2022-10-28 05:59:36 UTC
# 4  533239498623  2022-10-28 05:53:43 UTC
#
#                               IP Address  Proxiedhost IP Address  \
# 0                         181.117.236.52                     NaN
# 1                         181.117.228.39                     NaN
# 2  2800:810:54b:1139:84ac:b93f:cf4a:aa3a                     NaN
# 3  2800:810:54b:1139:84ac:b93f:cf4a:aa3a                     NaN
# 4  2800:810:54b:1139:84ac:b93f:cf4a:aa3a                     NaN
#
#   Is Non-routable IP Address  Activity Country  Activity Region  \
# 0                         No               NaN              NaN
# 1                         No               NaN              NaN
# 2                         No               NaN              NaN
# ...

# %%
#dfgoogle['Activity Timestamp'].str[:10]
dfgoogle['Activity Timestamp']=pd.to_datetime(dfgoogle['Activity Timestamp'].str[:10],format='%Y-%m-%d')

# %%
dfgoogle.rename(columns={'Activity Timestamp': 'date'}, inplace=True)
dfgoogle.rename(columns={'Product Name': 'product'}, inplace=True)
dfgoogle.head()
# Out:
#         Gaia ID       date                             IP Address  \
# 0  533239498623 2022-10-28                         181.117.236.52
# 1  533239498623 2022-10-28                         181.117.228.39
# 2  533239498623 2022-10-28  2800:810:54b:1139:84ac:b93f:cf4a:aa3a
# 3  533239498623 2022-10-28  2800:810:54b:1139:84ac:b93f:cf4a:aa3a
# 4  533239498623 2022-10-28  2800:810:54b:1139:84ac:b93f:cf4a:aa3a
#
#    Proxiedhost IP Address Is Non-routable IP Address  Activity Country  \
# 0                     NaN                         No               NaN
# 1                     NaN                         No               NaN
# 2                     NaN                         No               NaN
# 3                     NaN                         No               NaN
# 4                     NaN                         No               NaN
#
#    Activity Region  Activity City  \
# 0              NaN            NaN
# 1              NaN            NaN
# ...

# %%
##quiero ver las cantidades por producto para elegir si importo todos o no
sql="""select product, count(*) from dfgoogle group by product"""
#sql="""select * from dfgoogle where product='YouTube'"""
source = con.execute(sql).df()
source
# Out:
#         product  count_star()
# 0         Other        231850
# 1        Photos          5474
# 2         Gmail         32197
# 3       YouTube          3376
# 4          Play           301
# 5   Chrome Sync          1429
# 6         Drive          3284
# 7          Maps          7220
# 8      Calendar          1197
# 9        Search           423
# 10  Apps Search           376
# 11       Wallet             6

# %%
##inserto los ingreso de algunas appa que no tienen uso laboral YouTube,Play,Photos
sql="""insert into reactions (date_event, name, reaction) (SELECT date,'Google-apss',product FROM dfgoogle where product='YouTube' OR product='Play' OR product='Photos' )"""
source = con.execute(sql).df()
source.head()
# Out:
#    Count
# 0   9151

# %%
sql="""select name,reaction,count(*) from reactions group by name,reaction"""
source = con.execute(sql).df()
source
# Out:
#            name    reaction  count_star()
# 0      Facebook        LOVE          1039
# 1      Facebook        LIKE           172
# 2      Facebook     SUPPORT            48
# 3      Facebook        HAHA            27
# 4      Facebook       ANGER             2
# 5      Facebook         WOW             3
# 6      Facebook       SORRY             5
# 7      Facebook        post          2169
# 8      Linkedin        LIKE           407
# 9      Linkedin     EMPATHY             6
# 10     Linkedin  Connection           635
# 11     Linkedin     Message           122
# 12  Google-apss        Play           301
# 13  Google-apss     YouTube          3376
# 14  Google-apss      Photos          5474

# %%
sql="""select * from reactions """
source = con.execute(sql).df()

source.to_csv('/content/drive/MyDrive/_NAT2022/ITBA/Visualizacion datos/datos/reactions.csv')
